# %% [markdown]
# First try
# File > Download as > PDF via LaTex
#
# You may get the error:
# ![error](Error.png)

# %% [markdown]
# If so, run the next three cells below

# %%
# %conda update -n base -c conda-forge conda

# %%
# %conda install nbconvert[webpdf]
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# # All requested packages already installed.
#
# Retrieving notices: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.14.0
#   latest version: 23.1.0
#
# Please update conda by running
#
#     $ conda update -n base -c conda-forge conda

# %%
# %conda install pandoc
# Out:
# Collecting package metadata (current_repodata.json): ...working... done
# Solving environment: ...working... done
#
# ## Package Plan ##
#
#   environment location: C:\Users\z5074933\anaconda3
#
#   added / updated specs:
#     - pandoc
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     conda-4.14.0               |   py39hcbf5309_0         1.0 MB  conda-forge
#     pandoc-2.19.2              |       h57928b3_1        18.8 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        19.9 MB
#
# The following NEW packages will be INSTALLED:
#
#   pandoc             conda-forge/win-64::pandoc-2.19.2-h57928b3_1
#
# The following packages will be UPDATED:
#
#   conda                               4.13.0-py39hcbf5309_1 --> 4.14.0-py39hcbf5309_0
#
#
#
# Downloading and Extracting Packages
#
# conda-4.14.0         | 1.0 MB    |            |   0%
# conda-4.14.0         | 1.0 MB    | 1          |   2%
# conda-4.14.0         | 1.0 MB    | #####5     |  55%
# conda-4.14.0         | 1.0 MB    | ########## | 100%
# conda-4.14.0         | 1.0 MB    | ########## | 100%
#
# pandoc-2.19.2        | 18.8 MB   |            |   0%
# pandoc-2.19.2        | 18.8 MB   | 1          |   2%
# pandoc-2.19.2        | 18.8 MB   | 4          |   5%
# pandoc-2.19.2        | 18.8 MB   | 9          |   9%
# pandoc-2.19.2        | 18.8 MB   | #2         |  13%
# pandoc-2.19.2        | 18.8 MB   | #6         |  16%
# pandoc-2.19.2        | 18.8 MB   | #9         |  20%
# pandoc-2.19.2        | 18.8 MB   | ##3        |  23%
# pandoc-2.19.2        | 18.8 MB   | ##6        |  27%
# pandoc-2.19.2        | 18.8 MB   | ###        |  31%
# pandoc-2.19.2        | 18.8 MB   | ###3       |  34%
# pandoc-2.19.2        | 18.8 MB   | ###7       |  37%
# pandoc-2.19.2        | 18.8 MB   | ####       |  41%
# pandoc-2.19.2        | 18.8 MB   | ####4      |  45%
# pandoc-2.19.2        | 18.8 MB   | ####8      |  49%
# pandoc-2.19.2        | 18.8 MB   | #####2     |  52%
# pandoc-2.19.2        | 18.8 MB   | #####5     |  56%
# pandoc-2.19.2        | 18.8 MB   | #####9     |  60%
# pandoc-2.19.2        | 18.8 MB   | ######3    |  63%
# pandoc-2.19.2        | 18.8 MB   | ######6    |  67%
# pandoc-2.19.2        | 18.8 MB   | #######    |  71%
# pandoc-2.19.2        | 18.8 MB   | #######4   |  74%
# pandoc-2.19.2        | 18.8 MB   | #######8   |  78%
# pandoc-2.19.2        | 18.8 MB   | ########1  |  82%
# pandoc-2.19.2        | 18.8 MB   | ########5  |  86%
# pandoc-2.19.2        | 18.8 MB   | ########9  |  89%
# pandoc-2.19.2        | 18.8 MB   | #########2 |  92%
# pandoc-2.19.2        | 18.8 MB   | #########5 |  96%
# pandoc-2.19.2        | 18.8 MB   | #########9 |  99%
# pandoc-2.19.2        | 18.8 MB   | ########## | 100%
# Preparing transaction: ...working... done
# Verifying transaction: ...working... done
# Executing transaction: ...working... done
#
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# Restart the kernal by going to
# Kernel > Restart
# Now try again

# %% [markdown]
# If that doesnt work try the next one

# %%
pip install pandoc
# Out:
# Collecting pandoc
#   Downloading pandoc-2.3.tar.gz (33 kB)
# Collecting plumbum
#   Downloading plumbum-1.8.1-py3-none-any.whl (126 kB)
# Requirement already satisfied: ply in c:\users\z5074933\anaconda3\lib\site-packages (from pandoc) (3.11)
# Requirement already satisfied: pywin32 in c:\users\z5074933\anaconda3\lib\site-packages (from plumbum->pandoc) (228)
# Building wheels for collected packages: pandoc
#   Building wheel for pandoc (setup.py): started
#   Building wheel for pandoc (setup.py): finished with status 'done'
#   Created wheel for pandoc: filename=pandoc-2.3-py3-none-any.whl size=33289 sha256=79bb1f9d7b27a5d99b4aceffd7fc5665a74a9f1ddb239a975961d0d92909b970
#   Stored in directory: c:\users\z5074933\appdata\local\pip\cache\wheels\69\e6\a1\1daa96d919c9e09a71473649b717b8da286f3f8d7719d1cfc5
# Successfully built pandoc
# Installing collected packages: plumbum, pandoc
# Successfully installed pandoc-2.3 plumbum-1.8.1
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # Title
# ## sub title

# %%
1 + 1
# Out:
# 2

# %% [markdown]
# * point 1
# * point 2

# %%
import seaborn as sns
sns.set_theme(style="ticks")

dots = sns.load_dataset("dots")

# Define the palette as a list to specify exact values
palette = sns.color_palette("rocket_r")

# Plot the lines on two facets
sns.relplot(
    data=dots,
    x="time", y="firing_rate",
    hue="coherence", size="choice", col="align",
    kind="line", size_order=["T1", "T2"], palette=palette,
    height=5, aspect=.75, facet_kws=dict(sharex=False),
)

# %% [markdown]
# $$E=mc^2$$

# %% [markdown]
# $$
# \begin{align}
# a = \frac{1}{2} && b = \frac{1}{3} && c = \frac{1}{4} \\
# \alpha && \beta && \kappa
# \end{align}
# $$

# %%
import pandas as pd

data = {
  "calories": [420, 380, 390],
  "duration": [50, 40, 45]
}

#load data into a DataFrame object:
df = pd.DataFrame(data)

df
# Out:
#    calories  duration
# 0       420        50
# 1       380        40
# 2       390        45
